# %%
from Electrostatics import *

# %%
q = -2*10**-9
x,y = meshgrid(arange(-.5,.5, 0.06),arange(-.5,.5,0.06))
Vxy = pointPotential(x,y-.05,q,0.,0.)
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection ="3d")
p = ax.plot_surface(x, y, Vxy, rstride = 1, cstride = 1, linewidth=0, cmap=cm.coolwarm)
#normal x and y range changed to (-6,6)
cb = fig.colorbar(p, shrink =.5)

# %%
d = .01
q1 = 3*10**-9
cb = fig.colorbar(p, shrink=0.5)
Vxy = dipolePotential(x,y,q,d)
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection = '3d')
p = ax.plot_surface(x,y,Vxy, rstride=1, cstride=1, linewidth=0, cmap=cm.coolwarm)

# %% [markdown]
# Using Boolean masks to find data
# -

# %%
theta = arange(0.,2*pi, pi/100)
plot(theta,sin(theta))
show()

# %%
mask = (sin(theta)>0) & (sin(theta)<0.5)
#print mask
plot(theta,sin(theta),theta[mask], sin(theta[mask]))
show()

# %%
y = sin(theta[mask])
jj = (y ==max(y))
y[jj] = NaN

# %%
plot(theta, sin(theta))
plot(theta[mask], y, linewidth = 4)
show()

# %% [markdown]
# Interpolation
# =
#
# taking 2 endpoints and figuring out what the inbetween values should be

# %%
theta = arange(0.,2*pi, pi/10)
mask = (theta == .5)

# %%
theta = arange(0.,2*pi+.1, pi/10)
mask = (theta == .5)

newTheta = 0.5; newSin = 0.
from scipy.interpolate import interp1d
sinInterp = interp1d(theta, sin(theta))

newSin = sinInterp(newTheta)
print newSin

plot(theta,sin(theta),newTheta, newSin, 'r+', markersize = 20, markeredgewidth=3)
# Out:
# 0.473922198704
# [<matplotlib.lines.Line2D at 0x364ef10>,
#  <matplotlib.lines.Line2D at 0x37ac190>]

# %%
thetaNew = arange(0.,2*pi,pi/30)
sinNew = interp1d(theta,sin(theta))(thetaNew)

plot(theta, sin(theta), thetaNew, sinNew, 'r.')
show()

# %%
plot(thetaNew, sinNew - sin(thetaNew))
ylabel('difference between interp and exact value')

# %%
sinNewC = interp1d(theta, sin(theta), kind = 'cubic')(thetaNew)
subplot(2,1,1)
#cubic spline interpolation
plot(thetaNew, sinNew - sin(thetaNew), thetaNew, sinNewC - sin(thetaNew), 'r')
subplot(2,1,2)
plot(thetaNew, sinNewC-sin(thetaNew), 'r')
