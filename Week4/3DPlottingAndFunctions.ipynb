# %% [markdown]
# Electric dipole potential

# %% [markdown]
# \begin{equation}
# \ V(x,y) = \frac{kq}{\sqrt{x^2 + (y-d)^2}} - \frac{kq}{\sqrt{x^2 + (y+d)^2}}
# \end{equation}

# %%
#make the x-y grid to cover the plane -2<x<2 and -2<y<2
dx = 0.06
dy = 0.06
x,y = meshgrid(arange(-2.,2.,dx),arange(-2,2,dy))
x.ndim
y.shape

# %%
k=1; q=1; d=1
V = (k*q/(x**2 + (y - d)**2)**(1/2.) - (k*q/(x**2 + (y+d)**2)**(1/2.)))
G = exp((x**2)*-1 -(y**2))
print V
# Out:
# [[-0.1698635  -0.17826925 -0.18715865 ..., -0.19336737 -0.18414007
#   -0.17541494]
#  [-0.17127992 -0.17998007 -0.18920149 ..., -0.19565471 -0.18606779
#   -0.17702367]
#  [-0.17245961 -0.18144664 -0.19099347 ..., -0.19768747 -0.18774672
#   -0.17839056]
#  ...,
#  [ 0.17310174  0.18227437  0.19203282 ...,  0.19888408  0.18871243
#    0.17915368]
#  [ 0.17209427  0.1809867   0.19042599 ...,  0.19704029  0.18721662
#    0.1779635 ]
#  [ 0.17083282  0.17943553  0.18854686 ...,  0.19491887  0.18545135
#    0.17651294]]

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax =fig.gca(projection = '3d')
p = ax.plot_surface(x,y,V, rstride=1, cstride=1, linewidth =0, cmap=cm.rainbow)

# %%
levels = array([8,4,2,1,.5,.25,0,-.25,-.5,-1,-2,-4,-8])
contour(x,y,V, levels, cmap=cm.coolwarm)
show()

# %% [markdown]
# \begin{equation}
# G(x,y) = e^{-x^2 - y^2}
# \end{equation}

# %%
from mpl_toolkits.mplot3d import Axes3D
G = exp((x**2)*-1 -(y**2))
dx = 0.06
dy = 0.06
x,y = meshgrid(arange(-6.,6.,dx),arange(-6.,6.,dy))
x.ndim
y.shape
fig = figure()
ax =fig.gca(projection = '3d')
p = ax.plot_surface(x,y,G, rstride=1, cstride=1, linewidth =0, cmap=cm.rainbow)

levels = array([6,4,2,1,.5,.25,0,-.25,-.5,-1,-2,-4, -6])
show()


cset = ax.contour(x,y,G, zdir = 'x', offset = -6)

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
k = 8.9875518*10**9
q1 = -1*10**(-19) #left
q2 = 1*10**-19 #right

V = (k*q2/(x**2 + (y - d)**2)**(1/2.) - (k*q2/(x**2 + (y+d)**2)**(1/2.)))
V4 = (k*q1/((x-d)**2 + y**2)**(1/2.) - (k*q1/((x-d)**2 + y**2)**(1/2.)))
Vsum = V + V4

dx = 0.04
dy = 0.04
x,y = meshgrid(arange(-4.,4.,dx),arange(-4.,4.,dy))

fig = figure()
ax =fig.gca(projection = '3d')
p = ax.plot_surface(x,y,Vsum, rstride=1, cstride=1, linewidth =0, cmap=cm.rainbow)
